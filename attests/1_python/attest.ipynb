# %%
products = {'Oranges (packaged)': 114.99, 'Candy (Rotfront)': 280.0, 'Boiled sausage': 199.99, 'Juice J7 (orange)': 119.99, 'Trout (Seven Seas)': 399.99}
stocks = {'Boiled sausage': '33%', 'Juice J7 (orange)': '12%', 'Trout (Seven Seas)': '18%'}

def apply_discounts(products, stocks):
    prod_sale = {}
    for i in products.keys():
        if i in stocks:
            prod_sale[i] = products[i]*(100-int(stocks[i][:2]))/100
            prod_sale[i] = round(prod_sale[i], 2)
        else:
            prod_sale[i] = products[i]
    
    return prod_sale


print(apply_discounts(products, stocks))
# Out:
# {'Oranges (packaged)': 114.99, 'Candy (Rotfront)': 280.0, 'Boiled sausage': 133.99, 'Juice J7 (orange)': 105.59, 'Trout (Seven Seas)': 327.99}

# %%
import pandas as pd
bronze_top= pd.read_csv('bronze_top.csv', sep=';') 
bronze_top.rename(columns = {'Total':'Total_bronze'}, inplace=True)
silver_top= pd.read_csv('silver_top.csv', sep=';') 
silver_top.rename(columns = {'Total':'Total_silver'}, inplace=True)

merged = bronze_top.merge(
    silver_top,
    on='Country',
    how='inner'
)

# %%
import pandas as pd
solar_data = pd.read_csv('solarpower.csv')
solar_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 664 entries, 0 to 663
# Data columns (total 2 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   date       664 non-null    object
#  1   cum_power  664 non-null    float64
# dtypes: float64(1), object(1)
# memory usage: 10.5+ KB

# %%
for i in range(664):
    if solar_data.iloc[i]['cum_power'] == -1:
        print(solar_data.iloc[i-1]['cum_power'])
        print(solar_data.iloc[i])
        print(solar_data.iloc[i+1]['cum_power'])
# Out:
# 20248.0
# date         2017-02-15
# cum_power          -1.0
# Name: 45, dtype: object
# 20262.0
# 27986.0
# date         2018-10-10
# cum_power          -1.0
# Name: 647, dtype: object
# 28010.0

# %%
a = solar_data.iloc[45-1]['cum_power']
b = solar_data.iloc[45+1]['cum_power']
c = (a + b)/2
solar_data.at[45, 'cum_power'] = - 1

print(solar_data.iloc[45]['cum_power'])
# Out:
# -1.0

# %%
for i in range(664):
    if solar_data.iloc[i]['cum_power'] == -1:
        solar_data.at[i, 'cum_power']= (solar_data.iloc[i-1]['cum_power'] + solar_data.iloc[i+1]['cum_power'])/2
        print(solar_data.iloc[i]['cum_power'])
# Out:
# 20255.0
# 27998.0

# %%
solar_data['cum_power'].mean()
# Out:
# 23848.246987951807

# %%
solar_data['day_power'] = ''
solar_data.at[0, 'day_power'] = 0


for i in range(1, 664):
    solar_data.at[i, 'day_power'] = solar_data.iloc[i]['cum_power'] - solar_data.iloc[i-1]['cum_power']

solar_data.head()
# Out:
#          date  cum_power day_power
# 0  2017-01-01    20111.0         0
# 1  2017-01-02    20112.0       1.0
# 2  2017-01-03    20115.0       3.0
# 3  2017-01-04    20117.0       2.0
# 4  2017-01-05    20119.0       2.0

# %%
#solar_data.to_period('M')

solar_data['date'] = pd.to_datetime(solar_data['date'])

perda = solar_data.copy()
perda.head()
# Out:
#         date  cum_power day_power
# 0 2017-01-01    20111.0         0
# 1 2017-01-02    20112.0       1.0
# 2 2017-01-03    20115.0       3.0
# 3 2017-01-04    20117.0       2.0
# 4 2017-01-05    20119.0       2.0

# %%
perda['date'] = perda['date'].dt.to_period('M')
perda.head()
# Out:
#       date  cum_power day_power
# 0  2017-01    20111.0         0
# 1  2017-01    20112.0       1.0
# 2  2017-01    20115.0       3.0
# 3  2017-01    20117.0       2.0
# 4  2017-01    20119.0       2.0

# %%
tilt = perda.groupby(['date'])['day_power'].mean()
tilt.head()
# Out:
# date
# 2017-01     3.129032
# 2017-02     3.714286
# 2017-03    10.774194
# 2017-04         16.3
# 2017-05         19.0
# Freq: M, Name: day_power, dtype: object

# %%
import plotly.express as px

fig = px.bar(solar_data, x='date', y = 'day_power')
fig.show()
# Out:
# c:\Users\redd-ratt\AppData\Local\Programs\Python\Python311\Lib\site-packages\_plotly_utils\basevalidators.py:105: FutureWarning:
#
# The behavior of DatetimeProperties.to_pydatetime is deprecated, in a future version this will return a Series containing python datetime objects instead of an ndarray. To retain the old behavior, call `np.array` on the result
